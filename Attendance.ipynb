# %%
import pandas as pd 
import datetime
from random import randint
from time import sleep
import os

# %% [markdown]
# https://www.naturalstattrick.com/teamtable.php?fromseason=20222023&thruseason=20222023&stype=2&sit=ev&score=all&rate=y&team=all&loc=B&gpf=410&fd&td
# Another place to get stats.

# %%
url = 'https://www.hockey-reference.com/leagues/NHL_2023_games.html'
dfs = pd.read_html(url)
df = dfs[0]
dates = pd.to_datetime(df['Date'], format = "%Y-%m-%d").dt.date
print(df)
# Out:
#             Date               Visitor    G                   Home  G.1  \
# 0     2022-10-07       San Jose Sharks  1.0    Nashville Predators  4.0
# 1     2022-10-08   Nashville Predators  3.0        San Jose Sharks  2.0
# 2     2022-10-11  Vegas Golden Knights  4.0      Los Angeles Kings  3.0
# 3     2022-10-11   Tampa Bay Lightning  1.0       New York Rangers  3.0
# 4     2022-10-12        Seattle Kraken  4.0          Anaheim Ducks  5.0
# ...          ...                   ...  ...                    ...  ...
# 1307  2023-04-13  Vegas Golden Knights  NaN         Seattle Kraken  NaN
# 1308  2023-04-13     Detroit Red Wings  NaN    Tampa Bay Lightning  NaN
# 1309  2023-04-13     New Jersey Devils  NaN    Washington Capitals  NaN
# 1310  2023-04-14        Buffalo Sabres  NaN  Columbus Blue Jackets  NaN
# 1311  2023-04-14    Colorado Avalanche  NaN    Nashville Predators  NaN
#
#      Unnamed: 5     Att.   LOG            Notes
# 0           NaN  16648.0  2:43  at (Prague, CZ)
# ...

# %%
# Write DataFrame to Excel file
df.to_excel(r'C:\Users\roser\OneDrive\HB\St Marys\Classes\BIA 665 Decision Support Systems\Data\Courses.xlsx')
